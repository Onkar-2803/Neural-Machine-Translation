# %% [markdown]
# Download & Import libraries

# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Read files & store in dataframe

# %%
bible_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/bible-uedin.en-mr.mr')
bible_eng_f =open('/content/drive/MyDrive/NLP/NMT/Marathi-English/bible-uedin.en-mr.en')

gnome_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/GNOME.en-mr.mr')
gnome_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/GNOME.en-mr.en')

kde_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/KDE4.en-mr.mr')
kde_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/KDE4.en-mr.en')

qed_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/QED.en-mr.mr')
qed_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/QED.en-mr.en')

ubuntu_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/Ubuntu.en-mr.mr')
ubuntu_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/Ubuntu.en-mr.en')

wiki_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/wikimedia.en-mr.mr')
wiki_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/wikimedia.en-mr.en')

cc_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/MultiCCAligned.en-mr.mr')
cc_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/MultiCCAligned.en-mr.en')

ted_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/TED2020.en-mr.en')
ted_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/TED2020.en-mr.mr')

tico_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/tico-19.en-mr.en')
tico_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/tico-19.en-mr.mr')

wikimatrix_eng_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/WikiMatrix.en-mr.en')
wikimatrix_mar_f = open('/content/drive/MyDrive/NLP/NMT/Marathi-English/WikiMatrix.en-mr.mr')

# %%
lines = bible_mar_f.readlines()
bible_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = bible_eng_f.readlines()
bible_eng = pd.DataFrame(lines, columns = ["English"])

lines = gnome_mar_f.readlines()
gnome_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = gnome_eng_f.readlines()
gnome_eng = pd.DataFrame(lines, columns = ["English"])

lines = kde_mar_f.readlines()
kde_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = kde_eng_f.readlines()
kde_eng = pd.DataFrame(lines, columns = ["English"])

lines = qed_mar_f.readlines()
qed_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = qed_eng_f.readlines()
qed_eng = pd.DataFrame(lines, columns = ["English"])

lines = ubuntu_mar_f.readlines()
ubuntu_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = ubuntu_eng_f.readlines()
ubuntu_eng = pd.DataFrame(lines, columns = ["English"])

lines = wiki_mar_f.readlines()
wiki_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = wiki_eng_f.readlines()
wiki_eng = pd.DataFrame(lines, columns = ["English"])

many_things = pd.read_csv('/content/drive/MyDrive/NLP/NMT/Marathi-English/mar(many_things).txt',sep="\t" ,names = ["English","Marathi","extra"])

lines = cc_mar_f.readlines()
cc_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = cc_eng_f.readlines()
cc_eng = pd.DataFrame(lines, columns = ["English"])

lines = ted_mar_f.readlines()
ted_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = ted_eng_f.readlines()
ted_eng = pd.DataFrame(lines, columns = ["English"])

lines = tico_mar_f.readlines()
tico_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = tico_eng_f.readlines()
tico_eng = pd.DataFrame(lines, columns = ["English"])

lines = wikimatrix_mar_f.readlines()
wikimatrix_mar = pd.DataFrame(lines, columns = ["Marathi"])
lines = wikimatrix_eng_f.readlines()
wikimatrix_eng = pd.DataFrame(lines, columns = ["English"])

# %% [markdown]
# Concatenate english and marathi dataset

# %% [markdown]
# 1)Many things

# %%
many_things_new=many_things.drop(["extra"], axis=1)

# %%
many_things_new.tail(10)
# Out:
#                                                  English                                            Marathi
# 39951  I think it's unlikely that the next version of...  विंडोजची पुढची आवृत्ती या महीन्याच्या शेवटागोद...
# 39952  I think it's unlikely that the next version of...  विंडोजचा पुढचा वर्जन या महिन्याच्या शेवटागोदर ...
# 39953  I think it's unlikely that aliens similar to w...  चित्रपटांमध्ये दिसणार्‍या परग्रहवासींसारखे परग...
# 39954  When the tempura I make cools down, it immedia...  जेव्हा मी बनवलेला तेम्पुरा थंड होतो, तेव्हा त्...
# 39955  If religion were synonymous with morality, Bra...  जर धर्म व नीतिमत्ता समानार्थी शब्द असते, तर ब्...
# 39956  Just saying you don't like fish because of the...  हड्डींमुळे मासे आवडत नाही असं म्हणणं हे काय मा...
# 39957  The Japanese Parliament today officially elect...  आज जपानी संसदेने अधिकृतरित्या र्‍यौतारौ हाशिमो...
# 39958  Tom tried to sell his old VCR instead of throw...  टॉमने त्याचा जुना व्ही.सी.आर फेकून टाकण्याऐवजी...
# ...

# %%
many_things_new = many_things_new.replace('\n','', regex=True)

# %%
many_things_new
# Out:
#                                                  English                                            Marathi
# 0                                                    Go.                                                जा.
# 1                                                   Run!                                                पळ!
# 2                                                   Run!                                               धाव!
# 3                                                   Run!                                               पळा!
# 4                                                   Run!                                              धावा!
# ...                                                  ...                                                ...
# 39956  Just saying you don't like fish because of the...  हड्डींमुळे मासे आवडत नाही असं म्हणणं हे काय मा...
# 39957  The Japanese Parliament today officially elect...  आज जपानी संसदेने अधिकृतरित्या र्‍यौतारौ हाशिमो...
# ...

# %% [markdown]
# 2)Bibble

# %%
bible = pd.concat([bible_mar, bible_eng], axis=1)

# %%
bible.tail(10)
# Out:
#                                                  Marathi                                            English
# 60866  “पाहा! मी लवकर येत आहे, आणि माझे वेतन तुमच्याक...  And, behold, I come quickly; and my reward is ...
# 60867  मी अल्फा व ओमेगा, पहिला व अखेरचा, आरंभ आणि शेव...  I am Alpha and Omega, the beginning and the en...
# 60868  “जे आपले झगे साफ धुतात, ते धन्य! त्यांना जीवनी...  Blessed are they that do his commandments, tha...
# 60869  परंतु “कुत्रे” चेटकी, जादूटोणा करणारे, व्यभिचा...  For without are dogs, and sorcerers, and whore...
# 60870  “तुमच्या आपापल्या मंडळ्यांसाठी याबाबतीत साक्ष ...  I Jesus have sent mine angel to testify unto y...
# 60871  आत्मा आणि नवरी असे म्हणतात की, “ये! आणि जो कोण...  And the Spirit and the bride say, Come. And le...
# 60872  या पुस्तकात भविष्याकाळाबाबत नमूद केलेली वचने ज...  For I testify unto every man that heareth the ...
# 60873  आणि जो कोणी भविष्याकाळाबाबत संदेश देणाऱ्या या ...  And if any man shall take away from the words ...
# ...

# %%
bible.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
bible = bible.replace('\n','', regex=True)

# %%
bible.tail(10)
# Out:
#                                                  Marathi                                            English
# 60866  “पाहा! मी लवकर येत आहे, आणि माझे वेतन तुमच्याक...  And, behold, I come quickly; and my reward is ...
# 60867  मी अल्फा व ओमेगा, पहिला व अखेरचा, आरंभ आणि शेव...  I am Alpha and Omega, the beginning and the en...
# 60868  “जे आपले झगे साफ धुतात, ते धन्य! त्यांना जीवनी...  Blessed are they that do his commandments, tha...
# 60869  परंतु “कुत्रे” चेटकी, जादूटोणा करणारे, व्यभिचा...  For without are dogs, and sorcerers, and whore...
# 60870  “तुमच्या आपापल्या मंडळ्यांसाठी याबाबतीत साक्ष ...  I Jesus have sent mine angel to testify unto y...
# 60871  आत्मा आणि नवरी असे म्हणतात की, “ये! आणि जो कोण...  And the Spirit and the bride say, Come. And le...
# 60872  या पुस्तकात भविष्याकाळाबाबत नमूद केलेली वचने ज...  For I testify unto every man that heareth the ...
# 60873  आणि जो कोणी भविष्याकाळाबाबत संदेश देणाऱ्या या ...  And if any man shall take away from the words ...
# ...

# %% [markdown]
# 3)Gnome

# %%
gnome = pd.concat([gnome_mar, gnome_eng], axis=1)

# %%
gnome.tail(10)
# Out:
#                                                Marathi                                            English
# 139  केंद्रजोगी %s वरील तक्ता संवाद आढळले, निवड संव...  focusable %s has table interface, no selection...
# 140                %s कडे विना %s स्तरचे %s स्तर आहे\n                 %s has %s state without %s state\n
# 141                           %s संचाचे मालकीचे नाही\n                      %s does not belong to a set\n
# 142  %(rolename)s इन्डेक्स् %(num)d ओळ व स्तंभशी जु...  %(rolename)s index %(num)d does not match row ...
# 143  %(rolename)s मुख्य इन्डेक्स् %(num1)d ओळ व स्त...  %(rolename)s parent index %(num1)d does not ma...
# 144               %s वरील नाव किंवा वर्णन आढळले नाही\n                    %s has no name or description\n
# 145                              प्राधान्यता (_P)...\n                                  _Preferences...\n
# 146                                    विषयसूची (_C)\n                                        _Contents\n
# ...

# %%
gnome.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
gnome = gnome.replace('\n','', regex=True)

# %%
gnome = gnome.replace('%','', regex=True)

# %%
gnome.tail(10)
# Out:
#                                                Marathi                                            English
# 139  केंद्रजोगी s वरील तक्ता संवाद आढळले, निवड संवा...  focusable s has table interface, no selection ...
# 140                     s कडे विना s स्तरचे s स्तर आहे                      s has s state without s state
# 141                              s संचाचे मालकीचे नाही                         s does not belong to a set
# 142  (rolename)s इन्डेक्स् (num)d ओळ व स्तंभशी जुळत...  (rolename)s index (num)d does not match row an...
# 143  (rolename)s मुख्य इन्डेक्स् (num1)d ओळ व स्तंभ...  (rolename)s parent index (num1)d does not matc...
# 144                  s वरील नाव किंवा वर्णन आढळले नाही                       s has no name or description
# 145                                प्राधान्यता (_P)...                                    _Preferences...
# 146                                      विषयसूची (_C)                                          _Contents
# ...

# %% [markdown]
# 4)Kde

# %%
kde = pd.concat([kde_mar, kde_eng], axis=1)

# %%
kde.head(10)
# Out:
#                                              Marathi                                            English
# 0  '% 1' नामांकीत जुनी फाइल आधिपासूनच अस्तित्वात ...         An older file named '%1 'already exists.\n
# 1  '% 1' नुरूप नामांकीत फाइल आधिपासूनच अस्तित्वात...        A similar file named '%1 'already exists.\n
# 2  '% 1' नामांकीत नवी फाइल आधिपासूनच अस्तित्वात आ...          A newer file named '%1 'already exists.\n
# 3                                     स्त्रोत फाइल\n                                      Source File\n
# 4                                अस्तित्वातील फाइल\n                                    Existing File\n
# 5  उजवीकडील फाइलशी तुम्हाला अस्तत्वातील फाइल बदलव...  Would you like to replace the existing file wi...
# 6  स्थानीक यजमानावर ही ऑडिओ फाइल संचयीत नाही. दाख...  This audio file is not stored on the local hos...
# 7                     ऑडिओ फाइल दाखल करण्यास अपयशी\n                        Unable to load audio file\n
# ...

# %%
kde.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
kde = kde.replace('\n','', regex=True)

# %%
kde = kde.replace('%','', regex=True)

# %%
kde.tail(10)
# Out:
#                                                  Marathi                                            English
# 13210                                              कसोटी                                        Long Action
# 13211                            ' 2' उघडायचे? प्रकार: 1                                          KIdleTest
# 13212                     ' 3' उघडायचे? नाव: 2 प्रकार: 1                                  Open '2'? Type: 1
# 13213  हा विभाग करीता विशेष परवानगीची आवश्यकता आहे, स...                                             Abort?
# 13214                                           वगळा (A)                              Do wnload New Data...
# 13215  वगळा? Hot new stuff offers to Download New Dat...                                                 us
# 13216                                                 us  Konqueror has the ability to store the passwor...
# 13217                            दाखलन माहिती संचयीत करा          2 3 Unicode code point: 4 (In decimal: 5)
# ...

# %% [markdown]
# 5)Qed

# %%
qed = pd.concat([qed_mar, qed_eng], axis=1)

# %%
qed.head(10)
# Out:
#                                              Marathi                                            English
# 0  aata aaplya kade general tools aahet konchyahi...  We now have the general tools to really tackle...
# 1           एक शेतकरी ५३१ टमाटे उगवतो, तीन दिवसात.\n  A farmer grows 531 tomatoes and is able to sel...
# 2  आता ज़र सांगितले असेल कि टमाटान ची आवक १७६ नि क...  Given that his supply of tomatoes decreases by...
# 3                                   (सारंगी संगीत)\n                                   (violin music)\n
# 4                                  (संगीत समाप्ति)\n                                     (music ends)\n
# 5  शुभ प्रभात. आज मी इकडे आलोय ते स्वयंचलित, उडणा...  Good morning. I'm here today to talk about aut...
# 6  'आर' कमी करत जाल तशा. त्यातली सर्वांत महत्त्वा...  And there are lots of physical parameters that...
# 7  म्हणजे हा रोबो अर्थातच समर्थ आहे कुठलेही वळणदा...  So the robot is obviously capable of executing...
# ...

# %%
qed.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
qed = qed.replace('\n','', regex=True)

# %%
qed["English"] = qed["English"].str.lower()

# %%
qed.tail(10)
# Out:
#                                                 Marathi                                            English
# 1736  ती स्वीकारायला अवघड होती कारण प्लेटो हा कवींचा...  most of them were not so easy to take, because...
# 1737  त्यालुळे, पुराणकथा म्हणजे केवळ ऐकून मनोरंजन कर...  so, here, myths are not just something that yo...
# 1738  मर्त्य माणसं असं विचार करतात की देव जन्माला ये...  mortals consider that the gods are born and th...
# 1739  आपण आपल्या पुराणकथा आपल्या सांस्कृतिक मूल्यांध...  we make our mythic stories on the kinds of cul...
# 1740  लोक एकमेकांना ज्या प्रकारच्या पुराणकथा सांगतात...  so, according to xenophanes, culture actually ...
# 1741  आपण मध्ययुगातून पाहू. आणि आपल्या पुढच्या भागात...  we'll see through the middle ages, and then in...
# 1742  मी कॅटलीन प्रिएम, धार्मिक अभ्यासात द्विपदवीधार...  caitlin priem, religious studies major, and i ...
# 1743  शिशिर ऋतूत मी पदवीधारक होण्यासाठी तयार होत होत...  i was getting ready to graduate in the fall an...
# ...

# %% [markdown]
# 6)Ubuntu

# %%
ubuntu = pd.concat([ubuntu_mar, ubuntu_eng], axis=1)

# %%
ubuntu.tail(100)
# Out:
#                                                 Marathi                                            English
# 3118                   सत्र व्यवस्थापकाशी जुळवणी करा!\n                Can't connect to session manager!\n
# 3119                Dia आवृत्ती %s, %s %s कंपाईल केले\n                   Dia version %s, compiled %s %s\n
# 3120                                   Dia आवृत्ती %s\n                                   Dia version %s\n
# 3121  object-libs करीता शोधतेवेळी मानक घटक आढळले नाह...  Couldn't find standard objects when looking fo...
# 3122  '%s' मधिल object-libs करीता शोधतेवेळी मानक घटक...  Couldn't find standard objects when looking fo...
# ...                                                 ...                                                ...
# 3213  हे घटक पूर्ववत करा/पुन्हा करा करीता समर्थन पुर...  This object doesn't support Undo/Redo. Undo in...
# 3214                                       गुणधर्म...\n                                    Properties...\n
# ...

# %%
ubuntu.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
ubuntu = ubuntu.replace('\n','', regex=True)

# %%
ubuntu.tail(10)
# Out:
#                                                 Marathi                                            English
# 3208                                            प्रमाण:                                             Scale:
# 3209                                      असे गट्ट करा:                                            Fit to:
# 3210                                            यानुरूप                                                 by
# 3211                                  %0.3gcm x %0.3gcm                                  %0.3gcm x %0.3gcm
# 3212                                        पानाची रचना                                         Page Setup
# 3213  हे घटक पूर्ववत करा/पुन्हा करा करीता समर्थन पुर...  This object doesn't support Undo/Redo. Undo in...
# 3214                                         गुणधर्म...                                      Properties...
# 3215  तुम्ही वगळलेले ऑबजेक्ट मुख्य घटकात घट्ट बसत ना...  The object you dropped cannot fit into its par...
# ...

# %% [markdown]
# 7)Wiki

# %%
wiki = pd.concat([wiki_mar, wiki_eng], axis=1)

# %%
wiki.tail(10)
# Out:
# Empty DataFrame
# Columns: [Marathi, English]
# Index: []

# %%
wiki.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
wiki = wiki.replace('\n','', regex=True)

# %%
wiki.tail(10)
# Out:
# Empty DataFrame
# Columns: [Marathi, English]
# Index: []

# %% [markdown]
# 8)CC

# %%
cc = pd.concat([cc_mar, cc_eng], axis=1)

# %%
cc.tail(100)
# Out:
#                                                   Marathi                                            English
# 749866                     मॅग्नेशियम एल-थ्रेटेट पावडर \n  -Isoproterenol hydrochloride drug interactions \n
# 749867                    एक 2 बॅक एंड व्हेंटिलेटर आहे \n                    Have a 2 back end ventilator \n
# 749868                                 काय आणल आहेस….. \n                     Actually what happened is.. \n
# 749869                                  लॅट्वियन (474) \n                                   Casting (473) \n
# 749870  Aprilia Scarabeo 50 vs 100 पुनरावलोकन 1 Scoote...  APRILIA SR 50 SBK REPLICA – 2011 Scooters Mope...
# ...                                                   ...                                                ...
# 749961   हॉलिडे डीजे ड्रॉप - ट्रॅक लिस्टींग (खाली ऐका) \n       SKU: DJ DROPS 70 - #25 Category: DJ Drops \n
# 749962                                   रशियन (93810) \n                                     Boss (8310) \n
# ...

# %%
cc.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
cc = cc.replace('\n','', regex=True)

# %%
cc.tail(10)
# Out:
#                                                Marathi                                            English
# 749956                      एच.डी.पीटनेगधा जंभाईनितंब                             Hardcore fucking15 514
# 749957                                    भांडुप ईस्ट                                      Borivali East
# 749958                                  +19 बर्लिंगटन                                      +1 Burlington
# 749959                                 बॉंबशेल(12382)                                    Lipstick(12331)
# 749960                                        कायोउबि                                           MOKUYÔBI
# 749961  हॉलिडे डीजे ड्रॉप - ट्रॅक लिस्टींग (खाली ऐका)          SKU: DJ DROPS 70 - #25 Category: DJ Drops
# 749962                                  रशियन (93810)                                        Boss (8310)
# 749963                                          रशियन                                            Turkish
# ...

# %% [markdown]
# 9)TED

# %%
ted = pd.concat([ted_mar, ted_eng], axis=1)

# %%
ted.tail(100)
# Out:
#                                                  Marathi                                            English
# 22900  आपण या विचाराने सुरुवात करू या . कमीतून जास्त ...  Let's start in the spirit of more from less an...
# 22901  उदाहरणार्थ आपल्याला २०, ००० डॉलर नकोत ; आपल्या...  For example, we don't want 20,000 dollars; we ...
# 22902                 आपण १०० डॉलरमध्ये करू शकतो का ? \n                 Can we do it [for] 100 dollars? \n
# 22903                विकसनासाठी काल ? १० वर्षे नकोत . \n             Time for development, not 10 years. \n
# 22904                      आपल्याला घाई आहे ; ५ वर्षे \n                  We are in a hurry. Five years. \n
# ...                                                  ...                                                ...
# 22995  आणि सध्या मी जागतिक संशोधन केंद्राचा अध्यक्ष आ...  And currently I'm president of Global Research...
# 22996  मी एक जागतिक गट बनवितो आहे , जो जगापुढील मोठ्य...  I'm trying to build a global team, which will ...
# ...

# %%
ted.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
ted = ted.replace('\n','', regex=True)

# %%
ted.tail(100)
# Out:
#                                                  Marathi                                            English
# 22900  आपण या विचाराने सुरुवात करू या . कमीतून जास्त ...  Let's start in the spirit of more from less an...
# 22901  उदाहरणार्थ आपल्याला २०, ००० डॉलर नकोत ; आपल्या...  For example, we don't want 20,000 dollars; we ...
# 22902                   आपण १०० डॉलरमध्ये करू शकतो का ?                    Can we do it [for] 100 dollars?
# 22903                  विकसनासाठी काल ? १० वर्षे नकोत .                Time for development, not 10 years.
# 22904                        आपल्याला घाई आहे ; ५ वर्षे                     We are in a hurry. Five years.
# ...                                                  ...                                                ...
# 22995  आणि सध्या मी जागतिक संशोधन केंद्राचा अध्यक्ष आ...  And currently I'm president of Global Research...
# 22996  मी एक जागतिक गट बनवितो आहे , जो जगापुढील मोठ्य...  I'm trying to build a global team, which will ...
# ...

# %% [markdown]
# 10)TICO

# %%
tico = pd.concat([tico_mar, tico_eng], axis=1)

# %%
tico.tail(100)
# Out:
#                                                 Marathi                                            English
# 2971  COVID-19 मुळे दवाखान्यात दाखल झालेल्या लोकांपै...  Clotting abnormalities, specifically an increa...
# 2972  COVID-19 असलेल्या जवळ-जवळ 20-30% लोकांमध्ये उच...  Approximately 20-30% of people who present wit...
# 2973  ह्याच अहवालात असे सांगितले आहे की आजाराचे लक्ष...  According to the same report, the median time ...
# 2974  तरी पण, अतिदक्षता विभागांत दाखल केलेल्या रुग्ण...  However, patients transferred to an ICU had a ...
# 2975  प्रारंभी केसेसच्या अभ्यासांत आढळले की आजाराची ...  In a study of early cases, the median time fro...
# ...                                                 ...                                                ...
# 3066  तथापि, इतर तंत्र, जसे एन्टीबॉडी-डिपेंडंट सेल्य...  Other mechanisms however, such as antibody-dep...
# 3067  निष्क्रिय एन्टीबॉडी उपचाराच्या इतर स्वरूपाचा व...  Other forms of passive antibody therapy, for e...
# ...

# %%
tico.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
tico = tico.replace('\n','', regex=True)

# %%
tico.tail(100)
# Out:
#                                                 Marathi                                            English
# 2971  COVID-19 मुळे दवाखान्यात दाखल झालेल्या लोकांपै...  Clotting abnormalities, specifically an increa...
# 2972  COVID-19 असलेल्या जवळ-जवळ 20-30% लोकांमध्ये उच...  Approximately 20-30% of people who present wit...
# 2973  ह्याच अहवालात असे सांगितले आहे की आजाराचे लक्ष...  According to the same report, the median time ...
# 2974  तरी पण, अतिदक्षता विभागांत दाखल केलेल्या रुग्ण...  However, patients transferred to an ICU had a ...
# 2975  प्रारंभी केसेसच्या अभ्यासांत आढळले की आजाराची ...  In a study of early cases, the median time fro...
# ...                                                 ...                                                ...
# 3066  तथापि, इतर तंत्र, जसे एन्टीबॉडी-डिपेंडंट सेल्य...  Other mechanisms however, such as antibody-dep...
# 3067  निष्क्रिय एन्टीबॉडी उपचाराच्या इतर स्वरूपाचा व...  Other forms of passive antibody therapy, for e...
# ...

# %% [markdown]
# 11)Wiki Matrix

# %%
wikimatrix = pd.concat([wikimatrix_mar, wikimatrix_eng], axis=1)

# %%
wikimatrix.tail(100)
# Out:
#                                                   Marathi                                            English
# 124209                                  पाटील, श्री य. \n                                    Biner, Z. Ö. \n
# 124210  निसर्गाचा हा चमत्कार तासन् तास बघत रहावा वाटतो...        It's important to keep the wonder alive. \n
# 124211  त्यावेळी वज्जपूत्त संघाने स्वतंत्र्य वज्जपूत्त...  A newly formed cheerleader competition squad r...
# 124212                 नाणेफेक : बांग्लादेश - फलंदाजी. \n               Cricinfo: Bangladesh in Sri Lanka \n
# 124213        झाडाची उंची १५ ते २५ मीटर इतकी असू शकते. \n  The size of the fronds can be up to 50 by 25 c...
# ...                                                   ...                                                ...
# 124304  निदान : निदान शक्य तेवढे लवकर होणे या रोगात फा...  Positive means: Sun runs fast and culminates e...
# 124305               आता त्यांची संख्या ३०७६ इतकी आहे. \n                       His badge number is 4376. \n
# ...

# %%
wikimatrix.isna().sum()
# Out:
# Marathi    0
# English    0
# dtype: int64

# %%
wikimatrix = wikimatrix.replace('\n','', regex=True)

# %%
wikimatrix.tail(100)
# Out:
#                                                   Marathi                                            English
# 124209                                    पाटील, श्री य.                                       Biner, Z. Ö.
# 124210   निसर्गाचा हा चमत्कार तासन् तास बघत रहावा वाटतो.           It's important to keep the wonder alive.
# 124211  त्यावेळी वज्जपूत्त संघाने स्वतंत्र्य वज्जपूत्त...  A newly formed cheerleader competition squad r...
# 124212                   नाणेफेक : बांग्लादेश - फलंदाजी.                  Cricinfo: Bangladesh in Sri Lanka
# 124213          झाडाची उंची १५ ते २५ मीटर इतकी असू शकते.   The size of the fronds can be up to 50 by 25 c...
# ...                                                   ...                                                ...
# 124304  निदान : निदान शक्य तेवढे लवकर होणे या रोगात फा...  Positive means: Sun runs fast and culminates e...
# 124305                 आता त्यांची संख्या ३०७६ इतकी आहे.                          His badge number is 4376.
# ...

# %% [markdown]
# sentences: 1019506

# %%
df = wikimatrix.append([many_things_new, bible, gnome, kde, qed, ubuntu, wiki, cc, ted, tico])

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 Marathi                                            English
# 0     महाराष्ट्र शासनाच्या संकेतस्थळावरील उस्मानाबाद...  The treaty set aside Antarctica as a scientifi...
# 1     घाणेकर) डोंगरयात्रा (आनंद पाळंदे) दुर्गकथा (नि...      And in the mountains they suffer a calamity.
# 2                       मरिया (Mary) येशूची आई मारिया.                          Mariam (ማርያም) means Mary.
# 3           भासते ते तुझ्या ठायी, तू भूमि जल अग्नि तू।   Much to his indignation, they place him on the...
# 4     इस्ना अशरी समुदायाने धाकटा मुलगा मूसा काजिम या...  (The sole exception to this is Moses, who reta...
# ...                                                 ...                                                ...
# 3066  तथापि, इतर तंत्र, जसे एन्टीबॉडी-डिपेंडंट सेल्य...  Other mechanisms however, such as antibody-dep...
# ...

# %% [markdown]
# Status

# %% [markdown]
# **`wiki,qed,kde,bible`** -->done <br>
# **`ubuntu,gnome`** -->not done

# %% [markdown]
# Clean Ubuntu & Gnome dataset

# %% [markdown]
# Making model based on QED for sample

# %% [markdown]
# Saving Dataset

# %%
qed.to_csv(r"/content/drive/My Drive/Marathi-English/Cleaned Dataset/qed_cleaned.csv")
