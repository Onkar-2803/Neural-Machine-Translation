# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle  
import pandas as pd

# %%
raw_dataset =   pd.read_csv('/content/drive/My Drive/Marathi-English/Cleaned Dataset/qed_cleaned.csv')

# %%
raw_dataset=raw_dataset.drop(['Unnamed: 0'], axis = 1)

# %%
raw_dataset.tail(10)
# Out:
#                                                 Marathi                                            English
# 1736  ती स्वीकारायला अवघड होती कारण प्लेटो हा कवींचा...  most of them were not so easy to take, because...
# 1737  त्यालुळे, पुराणकथा म्हणजे केवळ ऐकून मनोरंजन कर...  so, here, myths are not just something that yo...
# 1738  मर्त्य माणसं असं विचार करतात की देव जन्माला ये...  mortals consider that the gods are born and th...
# 1739  आपण आपल्या पुराणकथा आपल्या सांस्कृतिक मूल्यांध...  we make our mythic stories on the kinds of cul...
# 1740  लोक एकमेकांना ज्या प्रकारच्या पुराणकथा सांगतात...  so, according to xenophanes, culture actually ...
# 1741  आपण मध्ययुगातून पाहू. आणि आपल्या पुढच्या भागात...  we'll see through the middle ages, and then in...
# 1742  मी कॅटलीन प्रिएम, धार्मिक अभ्यासात द्विपदवीधार...  caitlin priem, religious studies major, and i ...
# 1743  शिशिर ऋतूत मी पदवीधारक होण्यासाठी तयार होत होत...  i was getting ready to graduate in the fall an...
# ...

# %%
train, test = raw_dataset[:1300], raw_dataset[1300:1745]

# %%
train.tail(10)
# Out:
#                                                 Marathi                                            English
# 1290  (हशा) तर (टाळ्या) येथे मला सांगावयाचे आहे ग्रा...       (laughter) so - (applause) here's the thing:
# 1291  "कार्यालायचा धोरणात्मक निर्णय" विनोदी मुली काम...  pam from "the office," manga girls, a voluptuo...
# 1292  (हशा) अडाफ्रुट उद्योगाचा जनक लीमार फ्राइड रोसि...  (laughter) that's limor fried, the founder of ...
# 1293  "हिड्ड्न ब्रेन" पुस्तकात कसे आपले अबोध मन अध्य...  shankar vedantam is the author of "the hidden ...
# 1294  १९९४ मध्ये डलासला पुलित्झर पारितोषिक मिळाले. म...  the dallas morning news won a pulitzer prize i...
# 1295  JAWS येथे एका आदर्श स्त्रीला भेटल्यावर तिने या...  one of my board members is an editor at a majo...
# 1296     तर दुसऱ्या करवी दुसरा, त्याचा वेगळा ठसा असतो .  seen from another point of view, it gives quit...
# 1297  सर्व मुद्दे मांडल्यानेच तुम्हाला वास्तव कळते. ...  but it's only when you get the whole picture, ...
# ...

# %%
test.tail(10)
# Out:
#                                                 Marathi                                            English
# 1735  दुसरी महत्वाची व्यक्ती म्हणजे पाश्चात्य परंपरे...  and there are some decency police that are ope...
# 1736  ती स्वीकारायला अवघड होती कारण प्लेटो हा कवींचा...  most of them were not so easy to take, because...
# 1737  त्यालुळे, पुराणकथा म्हणजे केवळ ऐकून मनोरंजन कर...  so, here, myths are not just something that yo...
# 1738  मर्त्य माणसं असं विचार करतात की देव जन्माला ये...  mortals consider that the gods are born and th...
# 1739  आपण आपल्या पुराणकथा आपल्या सांस्कृतिक मूल्यांध...  we make our mythic stories on the kinds of cul...
# 1740  लोक एकमेकांना ज्या प्रकारच्या पुराणकथा सांगतात...  so, according to xenophanes, culture actually ...
# 1741  आपण मध्ययुगातून पाहू. आणि आपल्या पुढच्या भागात...  we'll see through the middle ages, and then in...
# 1742  मी कॅटलीन प्रिएम, धार्मिक अभ्यासात द्विपदवीधार...  caitlin priem, religious studies major, and i ...
# ...

# %%
dump(raw_dataset, open('/content/drive/MyDrive/Marathi-English/Cleaned Dataset/qed_raw_dataset.pkl', 'wb'))
dump(train, open('/content/drive/MyDrive/Marathi-English/Cleaned Dataset/qed_train.pkl', 'wb'))
dump(test, open('/content/drive/MyDrive/Marathi-English/Cleaned Dataset/qed_test.pkl', 'wb'))
